# %% [markdown]
# # Lab 1 (28F)

# %%
import requests
from bs4 import BeautifulSoup
import random

# %%
url = 'https://www.billboard.com/charts/hot-100/'
results = requests.get(url, headers = {"Accept-Language": "en-US"})

# %%
results.status_code    # all good so far
# Out:
# 200

# %%
soup = BeautifulSoup(results.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
# getting the song title from the top position:

soup.select('h3.c-title.a-no-trucate')[0].get_text(strip = True)
# Out:
# "We Don't Talk About Bruno"

# %%
# getting the artist/band from the top position:

soup.select('span.c-label.a-no-trucate')[0].get_text(strip = True)
# Out:
# 'Carolina Gaitan, Mauro Castillo, Adassa, Rhenzy Feliz, Diane Guerrero, Stephanie Beatriz & Encanto Cast'

# %%
# Creating a FOR loop to collect the song title and the artist:

song = []
artist = []
len_songs = len(soup.select('h3.c-title.a-no-trucate'))

# %%
len_songs
# Out:
# 100

# %%
for i in range(len_songs):
    song.append(soup.select('h3.c-title.a-no-trucate')[i].get_text(strip = True))
    artist.append(soup.select('span.c-label.a-no-trucate')[i].get_text(strip = True))

# %%
import pandas as pd

# %%
songs = pd.DataFrame({"song": song, "artist": artist})

# %%
songs
# Out:
#                                song  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                           abcdefu
# 3                        Easy On Me
# 4                     Super Gremlin
# ..                              ...
# 95                           Closer
# 96                    Cold December
# 97                Get Into It (Yuh)
# 98  All Too Well (Taylor's Version)
# 99            Give Heaven Some Hell
#
#                                                artist
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...
# 1                                       Glass Animals
# 2                                               GAYLE
# 3                                               Adele
# 4                                         Kodak Black
# ..                                                ...
# 95                          Saweetie Featuring H.E.R.
# 96                                           Rod Wave
# ...

# %%
songs['song_rank'] = np.arange(len(songs)) + 1

# %%
songs
# Out:
#                                song  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                           abcdefu
# 3                        Easy On Me
# 4                     Super Gremlin
# ..                              ...
# 95                           Closer
# 96                    Cold December
# 97                Get Into It (Yuh)
# 98  All Too Well (Taylor's Version)
# 99            Give Heaven Some Hell
#
#                                                artist  song_rank
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...          1
# 1                                       Glass Animals          2
# 2                                               GAYLE          3
# 3                                               Adele          4
# 4                                         Kodak Black          5
# ..                                                ...        ...
# 95                          Saweetie Featuring H.E.R.         96
# ...

# %%
col_names = ['song_rank', 'song', 'artist']
songs = songs.reindex(columns=col_names)

# %%
# Dataframe with the song name, the artist and its rang:
songs
# Out:
#     song_rank                             song  \
# 0           1        We Don't Talk About Bruno
# 1           2                       Heat Waves
# 2           3                          abcdefu
# 3           4                       Easy On Me
# 4           5                    Super Gremlin
# ..        ...                              ...
# 95         96                           Closer
# 96         97                    Cold December
# 97         98                Get Into It (Yuh)
# 98         99  All Too Well (Taylor's Version)
# 99        100            Give Heaven Some Hell
#
#                                                artist
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...
# 1                                       Glass Animals
# 2                                               GAYLE
# 3                                               Adele
# 4                                         Kodak Black
# ..                                                ...
# ...

# %%
list_songs = list(songs['song'])

# %%
list_songs
# Out:
# ["We Don't Talk About Bruno",
#  'Heat Waves',
#  'abcdefu',
#  'Easy On Me',
#  'Super Gremlin',
#  'Stay',
#  'Ghost',
#  'Shivers',
#  'Bad Habits',
#  'Cold Heart (PNAU Remix)',
#  'Thats What I Want',
#  'Need To Know',
#  'Surface Pressure',
#  'Pushin P',
#  'Industry Baby',
#  'Levitating',
#  'MAMIII',
#  'Nail Tech',
#  'Save Your Tears',
#  'Enemy',
#  'Big Energy',
#  'One Right Now',
#  'Hrs And Hrs',
#  'Woman',
#  "'Til You Can't",
#  'The Family Madrigal',
#  'Good 4 U',
#  'I Hate U',
#  'Light Switch',
#  'Sand In My Boots',
#  'Buy Dirt',
#  'Knife Talk',
#  'You Right',
#  'Love Nwantiti (Ah Ah Ah)',
#  'Fancy Like',
#  'One Mississippi',
#  'Meet Me At Our Spot',
#  'What Else Can I Do?',
#  'Fingers Crossed',
#  'Smokin Out The Window',
#  'Essence',
#  'Ahhh Ha',
#  'Still D.R.E.',
#  'Do We Have A Problem?',
#  'Oh My God',
#  'Dos Oruguitas',
#  'You Should Probably Leave',
#  'Sacrifice',
#  "Doin' This",
#  'Better Days',
#  'To Be Loved By You',
# ...

# %% [markdown]
# # Lab 2 (1M):

# %%
# collect user input with a prompt eg. 'what song do you like?'
cond = True
while cond:
    user_song = str(input('Hey! What song are you into right now? '))
    if user_song == '':
        print('Sorry, but you need to enter the title of a song you like.')
        continue
    else:
        # exact match:
        match = False
        for x in songs['song']:
            if user_song == x:
                print("Great! It's a hot match!")
                random_song = random.sample(list_songs, k = 1)
                if random_song != user_song:
                    print(random_song, sep = '')
                cond = False
                match = True
                break
        if match == False:
            for x in songs['song']:
                low = x.lower()

                if user_song in low:
                    positive = str(input(f'Do you mean "{x}"? (y/n): '))

                    if positive == 'y':
                        print("It's a hot match")
                        random_song = random.sample(list_songs, k = 1)
                        if random_song != user_song:
                            print(f'Now you can try {random_song}. I hope you like it :)')
                        cond = False
                        break
# Out:
# Hey! What song are you into right now? lo
# Do you mean "Love Nwantiti (Ah Ah Ah)"? (y/n): y
# It's a hot match
# Now you can try ['Beautiful Lies']. I hope you like it :)

# %% [markdown]
# # Lab 3 (2M):

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist = sp.user_playlist_tracks('ark90', '0TAeyT52Huma1pwlRfUE0O')

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['total']  # total songs of the list
# Out:
# 190

# %%
len(playlist['items'])    # it is the LIMIT (because it is a free API)
# Out:
# 100

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0TAeyT52Huma1pwlRfUE0O/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2018-12-12T21:37:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ark90'},
#     'href': 'https://api.spotify.com/v1/users/ark90',
#     'id': 'ark90',
#     'type': 'user',
#     'uri': 'spotify:user:ark90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yhD1KjhLxIETFF7vIRf8B'},
#        'href': 'https://api.spotify.com/v1/artists/6yhD1KjhLxIETFF7vIRf8B',
#        'id': '6yhD1KjhLxIETFF7vIRf8B',
#        'name': 'Against The Current',
#        'type': 'artist',
#        'uri': 'spotify:artist:6yhD1KjhLxIETFF7vIRf8B'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
# ...

# %%
playlist['items'][0]   # [0]['track'][0]['uri'][0]
# Out:
# {'added_at': '2018-12-12T21:37:02Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ark90'},
#   'href': 'https://api.spotify.com/v1/users/ark90',
#   'id': 'ark90',
#   'type': 'user',
#   'uri': 'spotify:user:ark90'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yhD1KjhLxIETFF7vIRf8B'},
#      'href': 'https://api.spotify.com/v1/artists/6yhD1KjhLxIETFF7vIRf8B',
#      'id': '6yhD1KjhLxIETFF7vIRf8B',
#      'name': 'Against The Current',
#      'type': 'artist',
#      'uri': 'spotify:artist:6yhD1KjhLxIETFF7vIRf8B'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
# ...

# %%
len(playlist['items'])
# Out:
# 100

# %%
playlist['items'][0]['track']['uri']
# Out:
# 'spotify:track:30vl7nX9kTYZRfr7kTi0jU'

# %%
user_id = 'ark90'

# %%
playlist_id = '0TAeyT52Huma1pwlRfUE0O'

# %%
def get_playlist_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
full_track_ids = get_playlist_tracks(user_id, playlist_id)

# %%
len(full_track_ids)
# Out:
# 190

# %%
full_track_ids
# Out:
# [{'added_at': '2018-12-12T21:37:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ark90'},
#    'href': 'https://api.spotify.com/v1/users/ark90',
#    'id': 'ark90',
#    'type': 'user',
#    'uri': 'spotify:user:ark90'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yhD1KjhLxIETFF7vIRf8B'},
#       'href': 'https://api.spotify.com/v1/artists/6yhD1KjhLxIETFF7vIRf8B',
#       'id': '6yhD1KjhLxIETFF7vIRf8B',
#       'name': 'Against The Current',
#       'type': 'artist',
#       'uri': 'spotify:artist:6yhD1KjhLxIETFF7vIRf8B'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
# ...

# %%
tracks_ids=[]
tracks_names=[]
tracks_artist=[]

# %%
# create lists that they'll be the columns from the df:

for item in full_track_ids:
    tracks_ids.append(item['track']['id'])
    tracks_names.append(item['track']['name'])
    tracks_artist.append(item['track']['artists'][0]['name'])

# %%
len(tracks_ids)
# Out:
# 190

# %%
len(tracks_names)
# Out:
# 190

# %%
len(tracks_artist)
# Out:
# 190

# %%
fem_playlist = pd.DataFrame({'title':tracks_names,'artist':tracks_artist,'song_ID':tracks_ids})

# %%
fem_playlist
# Out:
#                             title               artist                 song_ID
# 0    Running with the Wild Things  Against The Current  30vl7nX9kTYZRfr7kTi0jU
# 1    Don't Tell Me That It's Over        Amy Macdonald  2JvBjkB22q2jwwM1o6BGxU
# 2                        No Roots        Amy Macdonald  0yDVPfbgk5hQHtz69iVmMd
# 3                 Across The Nile        Amy Macdonald  0bMl8fizWhUOx9tJPMf5kg
# 4                  Mr Rock & Roll        Amy Macdonald  5iEgCmpSlIY7T6nXGStE29
# ..                            ...                  ...                     ...
# 185                    Terrifying      Gabriella Cilmi  7G5WgpNrdKf3pntgT9ASDw
# 186               I'm Only Lonely   Joanne Shaw Taylor  4bkjWF12Zz5Ri60OiHbNFV
# 187           Like a Woman Should          Hayley Mary  6mCgZmmTtKkT69j8UAhKO8
# 188             Keep On Lovin' Me   Joanne Shaw Taylor  1Nk3GiSbcYatdcKZLSfKUs
# 189             Don't Go Away Mad   Joanne Shaw Taylor  50EI2oq6ppdgWAHvCugL9J
#
# [190 rows x 3 columns]

# %% [markdown]
# ## Audio features:

# %%
import pandas as pd

# %%
audio_features = []
for x in range(len(full_track_ids)):
     audio_features.extend(sp.audio_features(tracks=full_track_ids[x]['track']['id']))

data = pd.DataFrame(audio_features)
data.head(3)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.448   0.930    9    -2.282     1       0.1210      0.000027
# 1         0.463   0.909    2    -4.671     0       0.0389      0.079400
# 2         0.427   0.688    3    -6.489     1       0.0506      0.268000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000     0.352    0.473  159.986  audio_features
# 1          0.000036     0.397    0.580  144.971  audio_features
# 2          0.008010     0.176    0.137  145.032  audio_features
#
#                        id                                   uri  \
# 0  30vl7nX9kTYZRfr7kTi0jU  spotify:track:30vl7nX9kTYZRfr7kTi0jU
# 1  2JvBjkB22q2jwwM1o6BGxU  spotify:track:2JvBjkB22q2jwwM1o6BGxU
# 2  0yDVPfbgk5hQHtz69iVmMd  spotify:track:0yDVPfbgk5hQHtz69iVmMd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/30vl7nX9kTYZ...
# ...

# %%
len(data)
# Out:
# 190

# %%
# Dataframe with the audio features based on the song ID:

data
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.448   0.930    9    -2.282     1       0.1210      0.000027
# 1           0.463   0.909    2    -4.671     0       0.0389      0.079400
# 2           0.427   0.688    3    -6.489     1       0.0506      0.268000
# 3           0.594   0.814    1    -6.047     1       0.0355      0.086800
# 4           0.610   0.858    9    -4.867     1       0.0318      0.028400
# ..            ...     ...  ...       ...   ...          ...           ...
# 185         0.397   0.944    3    -3.859     1       0.1190      0.001840
# 186         0.526   0.411    9    -9.383     1       0.0294      0.486000
# 187         0.460   0.900   11    -3.725     1       0.0674      0.002130
# 188         0.471   0.859    1    -4.915     1       0.1150      0.122000
# 189         0.470   0.903    6    -3.458     1       0.0501      0.047500
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...
