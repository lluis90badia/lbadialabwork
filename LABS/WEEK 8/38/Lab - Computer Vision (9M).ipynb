# %% [markdown]
# # Activity 1:

# %%
from IPython.core.display import display, HTML

# %%
display(HTML("""<a href = https://openaccess.thecvf.com/content_cvpr_2017_workshops/w16/papers/Yeh_Designing_a_Moral_CVPR_2017_paper.pdf>moral_cv</a>"""))
# Out:
# <a href = https://openaccess.thecvf.com/content_cvpr_2017_workshops/w16/papers/Yeh_Designing_a_Moral_CVPR_2017_paper.pdf>moral_cv</a>

# %% [markdown]
# This paper discuss about a method based on speculative analysis to categorise risks and detect which ones are most threatening and likely using Computer Vision (CV). But to make predictions, they would look into each case to provoke a dialogue to see the cases would cause discriminatory harm or cibersecurity issues.

# %% [markdown]
# # Activity 2:

# %%
# %matplotlib inline
from IPython.display import Image

# %%
Image('image.png')

# %% [markdown]
# # Activity 3:

# %% [markdown]
# My apologies, but I will skip this part of the lab to focus on my final project because it has to be worth it, so I need as much time as possible.
