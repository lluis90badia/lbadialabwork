# %% [markdown]
# # Lab - Customer Analysis Round 2 and 3

# %% [markdown]
# ## Show the dataframe shape:

# %%
# Importing the necessary libraries:

import pandas as pd
import numpy as np

# %%
mca = pd.read_csv('marketing_customer_analysis.csv')

# %%
mca.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## Standarise header names:

# %%
# We'll standarise them to lowercase and the spaces we'll replace with '_':

mca_headers = []
for column in range(len(mca.columns)):
    mca_headers.append(mca.columns[column].lower())

# %%
mca.columns = mca_headers

# %%
mca.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
# Replacing spaces to '_':
mca.columns = mca.columns.str.replace(' ', '_')

# %%
# Renaming the 'unnamed:_0' column to 'id':
new_name = {'unnamed:_0': 'id'}
mca.rename(columns = new_name, inplace = True)

# %%
mca.head(1)
# Out:
#    id customer    state  customer_lifetime_value response coverage education  \
# 0   0  DK49336  Arizona               4809.21696       No    Basic   College
#
#   effective_to_date employmentstatus gender  ...  number_of_open_complaints  \
# 0           2/18/11         Employed      M  ...                        0.0
#
#   number_of_policies     policy_type        policy  renew_offer_type  \
# 0                  9  Corporate Auto  Corporate L3            Offer3
#
#    sales_channel  total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0          Agent               292.8  Four-Door Car      Medsize          NaN
#
# [1 rows x 26 columns]

# %% [markdown]
# ## Which columns are numerical?

# %%
mca.select_dtypes([np.number])
# Out:
#           id  customer_lifetime_value  income  monthly_premium_auto  \
# 0          0              4809.216960   48029                    61
# 1          1              2228.525238       0                    64
# 2          2             14947.917300   22139                   100
# 3          3             22332.439460   49078                    97
# 4          4              9025.067525   23675                   117
# ...      ...                      ...     ...                   ...
# 10905  10905             15563.369440       0                   253
# 10906  10906              5259.444853   61146                    65
# 10907  10907             23893.304100   39837                   201
# 10908  10908             11971.977650   64195                   158
# 10909  10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# ...

# %% [markdown]
# ## Which columns are categorical?

# %%
mca.select_dtypes([np.object])
# Out:
# C:\Users\lluis\AppData\Local\Temp/ipykernel_11224/1945967944.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mca.select_dtypes([np.object])
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# ...

# %% [markdown]
# ## Check and deal with 'NaN' values:

# %%
# First of all, we use the function 'dropna()' and then restart the index:
mca = mca.dropna(how = 'all')

# After that, we check the % of NaN has each column:
nulls_df = pd.DataFrame(round(mca.isna().sum() / len(mca), 4) * 100)

# %%
nulls_df = nulls_df.rename(columns = {'index':'header', 0: 'prop_nulls'})

# %%
nulls_df
# Out:
#                                prop_nulls
# id                                   0.00
# customer                             0.00
# state                                5.78
# customer_lifetime_value              0.00
# response                             5.78
# coverage                             0.00
# education                            0.00
# effective_to_date                    0.00
# employmentstatus                     0.00
# gender                               0.00
# income                               0.00
# location_code                        0.00
# marital_status                       0.00
# monthly_premium_auto                 0.00
# months_since_last_claim              5.80
# months_since_policy_inception        0.00
# number_of_open_complaints            5.80
# number_of_policies                   0.00
# policy_type                          0.00
# policy                               0.00
# renew_offer_type                     0.00
# ...

# %%
# Column 'state' --> we'll replace NaN with 'Unknown'
mca['state'] = mca['state'].fillna("Unknown")

# %%
# It is necessary to change the name of the variable, otherwise, we'll get an error:
nulls_df2 = pd.DataFrame(round(mca.isna().sum() / len(mca), 4) * 100)

# %%
nulls_df2 = nulls_df2.rename(columns = {'index':'header', 0: 'prop_nulls'})
nulls_df2
# Out:
#                                prop_nulls
# id                                   0.00
# customer                             0.00
# state                                0.00
# customer_lifetime_value              0.00
# response                             5.78
# coverage                             0.00
# education                            0.00
# effective_to_date                    0.00
# employmentstatus                     0.00
# gender                               0.00
# income                               0.00
# location_code                        0.00
# marital_status                       0.00
# monthly_premium_auto                 0.00
# months_since_last_claim              5.80
# months_since_policy_inception        0.00
# number_of_open_complaints            5.80
# number_of_policies                   0.00
# policy_type                          0.00
# policy                               0.00
# renew_offer_type                     0.00
# ...

# %%
# Because 'vehicle_type' has > 50% of NaN values, we'll drop that column:
mca = mca.drop(['vehicle_type'], axis = 1)

# %%
nulls_df3 = pd.DataFrame(round(mca.isna().sum() / len(mca), 4) * 100)

# %%
nulls_df3 = nulls_df3.rename(columns = {'index':'header', 0: 'prop_nulls'})
nulls_df3
# Out:
#                                prop_nulls
# id                                   0.00
# customer                             0.00
# state                                0.00
# customer_lifetime_value              0.00
# response                             5.78
# coverage                             0.00
# education                            0.00
# effective_to_date                    0.00
# employmentstatus                     0.00
# gender                               0.00
# income                               0.00
# location_code                        0.00
# marital_status                       0.00
# monthly_premium_auto                 0.00
# months_since_last_claim              5.80
# months_since_policy_inception        0.00
# number_of_open_complaints            5.80
# number_of_policies                   0.00
# policy_type                          0.00
# policy                               0.00
# renew_offer_type                     0.00
# ...

# %%
# Now, we'll deal with the numerical columns with NaN:
mslc = mca['months_since_last_claim'].median()
mca['months_since_last_claim'] = mca['months_since_last_claim'].fillna(mslc)

nooc = mca['number_of_open_complaints'].median()
mca['number_of_open_complaints'] = mca['number_of_open_complaints'].fillna(nooc)
mca.head(1)
# Out:
#    id customer    state  customer_lifetime_value response coverage education  \
# 0   0  DK49336  Arizona               4809.21696       No    Basic   College
#
#   effective_to_date employmentstatus gender  ...  \
# 0           2/18/11         Employed      M  ...
#
#    months_since_policy_inception number_of_open_complaints number_of_policies  \
# 0                             52                       0.0                  9
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
#
#    total_claim_amount  vehicle_class vehicle_size
# 0               292.8  Four-Door Car      Medsize
#
# [1 rows x 25 columns]

# %%
# The rest of categorical columns:
mca['response'] = mca['response'].fillna("Unknown")
mca['vehicle_class'] = mca['vehicle_class'].fillna("Unknown")
mca['vehicle_size'] = mca['vehicle_size'].fillna("Unknown")

# %%
nulls_df4 = pd.DataFrame(round(mca.isna().sum() / len(mca), 4) * 100)
nulls_df4 = nulls_df4.rename(columns = {'index':'header', 0: 'prop_nulls'})
nulls_df4      # output: no NULL values
# Out:
#                                prop_nulls
# id                                    0.0
# customer                              0.0
# state                                 0.0
# customer_lifetime_value               0.0
# response                              0.0
# coverage                              0.0
# education                             0.0
# effective_to_date                     0.0
# employmentstatus                      0.0
# gender                                0.0
# income                                0.0
# location_code                         0.0
# marital_status                        0.0
# monthly_premium_auto                  0.0
# months_since_last_claim               0.0
# months_since_policy_inception         0.0
# number_of_open_complaints             0.0
# number_of_policies                    0.0
# policy_type                           0.0
# policy                                0.0
# renew_offer_type                      0.0
# ...

# %%
mca['number_of_open_complaints'].unique()
# Out:
# array([0., 3., 1., 2., 4., 5.])

# %% [markdown]
# ## Datetime format:

# %% [markdown]
# ### Extract the months from the dataset and store in a separate column:

# %%
# We'll import the necessary libraries:
import time
from datetime import date

# %%
mca['month'] = pd.DatetimeIndex(mca['effective_to_date']).month
mca.head(1)   # mca['month'] = df['effective_to_date'].dt.strftime('%b') doesn't work
# Out:
#    id customer    state  customer_lifetime_value response coverage education  \
# 0   0  DK49336  Arizona               4809.21696       No    Basic   College
#
#   effective_to_date employmentstatus gender  ...  number_of_open_complaints  \
# 0           2/18/11         Employed      M  ...                        0.0
#
#   number_of_policies     policy_type        policy  renew_offer_type  \
# 0                  9  Corporate Auto  Corporate L3            Offer3
#
#    sales_channel  total_claim_amount  vehicle_class vehicle_size month
# 0          Agent               292.8  Four-Door Car      Medsize     2
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
first_q = [1, 2, 3]
months = mca[mca.month.isin(first_q)]

# %%
months
# Out:
#           id customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
# ...

# %% [markdown]
# ## BONUS: Put all the previously mentioned data transformations into a function.

# %% [markdown]
# # Customer Analysis Round 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## DataFrame info:

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %% [markdown]
# ## DataFrame description:

# %%
mca.describe()
# Out:
#                  id  customer_lifetime_value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly_premium_auto  months_since_last_claim  \
# count          10910.000000             10910.000000
# mean              93.196059                15.082401
# std               34.442532                 9.787208
# min               61.000000                 0.000000
# 25%               68.000000                 7.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %% [markdown]
# ## Show a plot of the total number of responses (for each response type - "Yes"/"No"):

# %%
mca.response.unique()
# Out:
# array(['No', 'Yes', 'Unknown'], dtype=object)

# %%
mca['response'].value_counts().plot(kind = 'bar', color = 'orange')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Show a plot of the rate of the response types by each Sales Channel:

# %%
query1 = mca.query('response == ["Yes", "No"]')

# %%
query1['response'].value_counts().plot(kind = 'bar', color = 'orange')
# Out:
# <AxesSubplot:>

# %%
query1.groupby('sales_channel')['response'].value_counts().unstack().plot.bar(ylabel= 'Responses')
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='Responses'>

# %% [markdown]
# ## Show a plot of the distribution of the Total Claim Amount, broken down by response type:

# %%
# Boxplot for 'Yes / No' responses:

# %%
sns.set(rc={"figure.figsize":(15, 15)})
sns.boxplot(x=query1['response'], y='total_claim_amount', data=mca)
# Out:
# <AxesSubplot:xlabel='response', ylabel='total_claim_amount'>

# %%
# Distribution plot:

# %%
mca.groupby(query1['response'])['total_claim_amount'].hist(bins=20, legend = True);

# %% [markdown]
# ## Create similar plots like in the task before, but for Income:

# %%
mca.groupby(query1['response'])['income'].hist(bins=20, legend = True);

# %% [markdown]
# ## Create a scatterplot between Total Claim Amount and Income:

# %%
plt.scatter(x = 'income', y = 'total_claim_amount', data = mca, color = 'orange', marker = '*')
