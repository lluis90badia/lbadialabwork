# %% [markdown]
# # Lluis Badia - Lab Jupyter Notebook

# %% [markdown]
# ## Purpose
# *The purpose of this Jupyter Notebook is to introduce the name of the user and her/his holidays preference with a picture and a link to a YouTube video of that place.*

# %% [markdown]
# ## Username

# %%
username = str(input("Please enter your name: "))
print(f"{username}, welcome to your first Jupyter Notebook!")
# Out:
# Please enter your name: Lluis
# Lluis, welcome to your first Jupyter Notebook!

# %% [markdown]
# ![Lluis1-petita.jpg](attachment:Lluis1-petita.jpg)

# %% [markdown]
# ## Destination

# %%
destination = str(input("Please enter the name of your holiday preference: "))
print(f"Fantastic! {destination} is a great place to visit!")
# Out:
# Please enter the name of your holiday preference: Stockholm
# Fantastic! Stockholm is a great place to visit!

# %% [markdown]
# ![stockholm.png](attachment:stockholm.png)

# %% [markdown]
# ## Things to do

# %% [markdown]
# **Top 3 of things to do:**
#
# - *Sightseeing*
# - *Visiting some museums*
# - *Going to a concert*

# %% [markdown]
# ## Link YouTube video

# %% [markdown]
# ***Link of the destination:***
#
# https://www.youtube.com/watch?v=DS_6M3Nqh7k

# %% [markdown]
# ## Function annotations

# %%
# Function annotations:

# input(): This function allows to introduce (input) information from the user.
# print(): This function read (print) the specified message or output to the screen.
